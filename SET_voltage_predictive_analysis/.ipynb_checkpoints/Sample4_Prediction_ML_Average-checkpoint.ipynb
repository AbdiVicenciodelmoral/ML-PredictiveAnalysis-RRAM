# %%
import pandas as pd
import numpy as np
import nbimporter
from MLModels import mlModels
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
#display(setVoltageDf)

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp3 = setVoltageDf.loc['Sample_3']
smp3_X = smp3.drop('Set_voltage_kde',axis=1)
smp3_y = smp3['Set_voltage_kde']
display(smp3_X)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
#
#           Top electrode material  SET Voltage
# Sample
# Sample_3                       2          0.0
# Sample_3                       2          0.2
# Sample_3                       2          0.4
# Sample_3                       2          0.6
# Sample_3                       2          0.8
# Sample_3                       2          1.0
# Sample_3                       2          1.2
# Sample_3                       2          1.4
# Sample_3                       2          1.6
# Sample_3                       2          1.8
# Sample_3                       2          2.0
# Sample_3                       2          2.2
# Sample_3                       2          2.4
# Sample_3                       2          2.6
# Sample_3                       2          2.8
# Sample_3                       2          3.0
# Sample_3                       2          3.2
# Sample_3                       2          3.4
# Sample_3                       2          3.6
# Sample_3                       2          3.8
# Sample_3                       2          4.0
# Sample_3                       2          4.2
# Sample_3                       2          4.4
# Sample_3                       2          4.6
# Sample_3                       2          4.8
# Sample_3                       2          5.0
# Sample_3                       2          5.2
# Sample_3                       2          5.4
# Sample_3                       2          5.6
# Sample_3                       2          5.8
# Sample_3                       2          6.0
# Sample_3                       2          6.2
# Sample_3                       2          6.4
# Sample_3                       2          6.6
# Sample_3                       2          6.8
# Sample_3                       2          7.0
# Sample_3                       2          7.2
# Sample_3                       2          7.4
# Sample_3                       2          7.6
# Sample_3                       2          7.8
# Sample_3                       2          8.0
# Sample_3                       2          8.2
# Sample_3                       2          8.4
# Sample_3                       2          8.6
# Sample_3                       2          8.8
# Sample_3                       2          9.0
# Sample_3                       2          9.2
# Sample_3                       2          9.4
# Sample_3                       2          9.6
# Sample_3                       2          9.8
# Sample_3                       2         10.0

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_3')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_3'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
reg_Models = mlModels()
reg_Models.runModels(X,y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
#
#
# Random Forest Regression Mean squared error: 0.00009
# Coefficient of determination: 0.93731
#
#
# Adaboost Regression Mean squared error: 0.00135
# Coefficient of determination: 0.06895

# %%
smp3_pred_ada = smp3_X.copy()
smp3_pred_ada['Set_voltage_kde'] = reg_Models.newSample(smp3_X,'ada')
#smp3_pred_ada
# Out:
# Ada Boost:  [0.09767458 0.09767458 0.09767458 0.15692582 0.1742936  0.22582799
#  0.22582799 0.22582799 0.19374278 0.19374278 0.19374278 0.19374278
#  0.19374278 0.19374278 0.15692582 0.15324909 0.15324909 0.15324909
#  0.15692582 0.13006135 0.13006135 0.13006135 0.12467025 0.12168698
#  0.10290792 0.09548242 0.09520766 0.08987162 0.05742036 0.03982479
#  0.03197183 0.0196366  0.0196366  0.0196366  0.01591046 0.01591046
#  0.01591046 0.01591046 0.01591046 0.01591046 0.01591046 0.01591046
#  0.01591046 0.01591046 0.01591046 0.01591046 0.01591046 0.01591046
#  0.01591046 0.01591046 0.01591046]

# %%
smp3_pred_rfr = smp3_X.copy()
smp3_pred_rfr['Set_voltage_kde'] = reg_Models.newSample(smp3_X,'rfr')
#smp3_pred_rfr
# Out:
# Random Forest:  [0.02319279 0.03149112 0.06181692 0.17513286 0.2282304  0.20572167
#  0.17899649 0.190727   0.18063816 0.15674401 0.14347583 0.13586787
#  0.15324258 0.15959058 0.16265567 0.17231471 0.18398304 0.18929452
#  0.19506227 0.17022906 0.1574547  0.13506748 0.10682517 0.09942703
#  0.08091157 0.06101581 0.03827202 0.02393386 0.02251433 0.02038495
#  0.01948907 0.01797229 0.01747166 0.01730549 0.01488965 0.01428611
#  0.01495007 0.01960803 0.02348711 0.0301727  0.03388149 0.03598116
#  0.03517591 0.02918616 0.023621   0.01763986 0.01201463 0.00789537
#  0.00555976 0.00549298 0.0073869 ]

# %%
# Load the dataframes

setVoltageDf =  pd.read_csv('process_data/setVoltage_KDE.csv')

setVoltageDf.set_index('Sample', inplace=True)
setVoltageDf = setVoltageDf.drop(index='Sample_1')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_1'
if s_idx in idx:
    raise ValueError('Sample in Training set')
display(setVoltageDf)

X_train = setVoltageDf.drop('Set_voltage_kde',axis=1)
y_train = setVoltageDf['Set_voltage_kde']

# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1000         
}

model = NeuralNet(X_scaled,y_train,parameters).to(device)
model.train_model()
scaled_smp3_X = standard_scaler.transform(smp3_X)
smp3_pred_FFN = model.testSample(scaled_smp3_X,smp3_X)
display(smp3_pred_FFN)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_2                       2         1.40         0.101198
# Sample_2                       2         5.00         0.111477
# Sample_2                       2         0.77         0.075984
# Sample_2                       2         1.50         0.103259
# Sample_2                       2         2.92         0.206484
# ...                          ...          ...              ...
# Sample_8                       2         3.20         0.271727
# Sample_8                       2         4.70         0.272732
# Sample_8                       2         3.06         0.268237
# Sample_8                       2         4.74         0.271047
# Sample_8                       2         2.64         0.210634
#
# [780 rows x 7 columns]
# Epoch [10/1000], Loss: 0.0295, R-squared: -0.1239, MAPE: 120.2183%
# Epoch [20/1000], Loss: 0.0229, R-squared: 0.1296, MAPE: 95.6564%
# Epoch [30/1000], Loss: 0.0184, R-squared: 0.3012, MAPE: 73.9806%
# Epoch [720/1000], Loss: 0.0028, R-squared: 0.8936, MAPE: 32.5234%
# Epoch [730/1000], Loss: 0.0024, R-squared: 0.9073, MAPE: 29.1622%
# Epoch [740/1000], Loss: 0.0025, R-squared: 0.9050, MAPE: 28.9495%
# Epoch [750/1000], Loss: 0.0024, R-squared: 0.9093, MAPE: 28.3222%
# Epoch [760/1000], Loss: 0.0026, R-squared: 0.9001, MAPE: 28.2356%
# Epoch [770/1000], Loss: 0.0025, R-squared: 0.9060, MAPE: 32.3953%
# Epoch [780/1000], Loss: 0.0022, R-squared: 0.9158, MAPE: 28.5067%
# Epoch [790/1000], Loss: 0.0025, R-squared: 0.9052, MAPE: 26.2437%
# Epoch [800/1000], Loss: 0.0025, R-squared: 0.9040, MAPE: 29.3151%
# Epoch [810/1000], Loss: 0.0021, R-squared: 0.9215, MAPE: 23.9908%
# Epoch [820/1000], Loss: 0.0024, R-squared: 0.9067, MAPE: 29.5410%
# Epoch [830/1000], Loss: 0.0023, R-squared: 0.9143, MAPE: 28.9731%
# Epoch [840/1000], Loss: 0.0023, R-squared: 0.9132, MAPE: 26.9321%
# Epoch [850/1000], Loss: 0.0020, R-squared: 0.9222, MAPE: 23.3806%
# Epoch [860/1000], Loss: 0.0025, R-squared: 0.9034, MAPE: 29.8642%
# Epoch [870/1000], Loss: 0.0024, R-squared: 0.9086, MAPE: 29.1790%
# Epoch [880/1000], Loss: 0.0023, R-squared: 0.9136, MAPE: 29.5303%
# Epoch [890/1000], Loss: 0.0023, R-squared: 0.9127, MAPE: 28.1546%
# Epoch [900/1000], Loss: 0.0024, R-squared: 0.9086, MAPE: 26.7756%
# Epoch [910/1000], Loss: 0.0020, R-squared: 0.9230, MAPE: 26.0100%
# Epoch [920/1000], Loss: 0.0024, R-squared: 0.9078, MAPE: 27.4120%
# Epoch [930/1000], Loss: 0.0025, R-squared: 0.9047, MAPE: 27.9657%
# Epoch [940/1000], Loss: 0.0021, R-squared: 0.9209, MAPE: 26.2527%
# Epoch [950/1000], Loss: 0.0023, R-squared: 0.9118, MAPE: 29.7917%
# Epoch [960/1000], Loss: 0.0020, R-squared: 0.9225, MAPE: 26.7726%
# Epoch [970/1000], Loss: 0.0020, R-squared: 0.9234, MAPE: 27.3610%
# Epoch [980/1000], Loss: 0.0022, R-squared: 0.9175, MAPE: 28.8509%
# Epoch [990/1000], Loss: 0.0023, R-squared: 0.9141, MAPE: 23.5533%
# Epoch [1000/1000], Loss: 0.0022, R-squared: 0.9175, MAPE: 26.5288%
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            896
# ├─LeakyReLU: 1-2                         --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            16,512
# ├─LeakyReLU: 1-5                         --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            129
# =================================================================
# Total params: 17,537
# Trainable params: 17,537
# Non-trainable params: 0
# =================================================================
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_3                       2          0.0         0.115950
# Sample_3                       2          0.2         0.119921
# Sample_3                       2          0.4         0.124369
# Sample_3                       2          0.6         0.129203
# Sample_3                       2          0.8         0.134122
# Sample_3                       2          1.0         0.139238
# Sample_3                       2          1.2         0.145110
# Sample_3                       2          1.4         0.151164
# Sample_3                       2          1.6         0.157312
# Sample_3                       2          1.8         0.162323
# Sample_3                       2          2.0         0.164460
# Sample_3                       2          2.2         0.166390
# Sample_3                       2          2.4         0.168126
# Sample_3                       2          2.6         0.169568
# Sample_3                       2          2.8         0.170869
# Sample_3                       2          3.0         0.172169
# Sample_3                       2          3.2         0.173470
# Sample_3                       2          3.4         0.174100
# Sample_3                       2          3.6         0.173802
# Sample_3                       2          3.8         0.172628
# Sample_3                       2          4.0         0.170651
# Sample_3                       2          4.2         0.168072
# Sample_3                       2          4.4         0.165402
# Sample_3                       2          4.6         0.162412
# Sample_3                       2          4.8         0.159333
# Sample_3                       2          5.0         0.154979
# Sample_3                       2          5.2         0.150224
# Sample_3                       2          5.4         0.143813
# Sample_3                       2          5.6         0.136461
# Sample_3                       2          5.8         0.130147
# Sample_3                       2          6.0         0.125741
# Sample_3                       2          6.2         0.121254
# Sample_3                       2          6.4         0.117204
# Sample_3                       2          6.6         0.113452
# Sample_3                       2          6.8         0.109900
# Sample_3                       2          7.0         0.106319
# Sample_3                       2          7.2         0.102836
# Sample_3                       2          7.4         0.099496
# Sample_3                       2          7.6         0.096514
# Sample_3                       2          7.8         0.093494
# Sample_3                       2          8.0         0.090438
# Sample_3                       2          8.2         0.087621
# Sample_3                       2          8.4         0.084900
# Sample_3                       2          8.6         0.082170
# Sample_3                       2          8.8         0.079322
# Sample_3                       2          9.0         0.076457
# Sample_3                       2          9.2         0.073583
# Sample_3                       2          9.4         0.070709
# Sample_3                       2          9.6         0.067835
# Sample_3                       2          9.8         0.064961
# Sample_3                       2         10.0         0.062076

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
def moving_average(data, window_size):
    ma = np.zeros(len(data))
    for i in range(window_size, len(data) + 1):
        ma[i - 1] = np.mean(data[i - window_size:i])
    return ma

# Set the window size for the moving average
window_size = 4

# Calculate the moving average of the predictions

smooth_smp_FFN = smp3_pred_FFN.copy()
smooth_smp_FFN['Set_voltage_kde'] = moving_average(smp3_pred_FFN['Set_voltage_kde'], window_size)

# Now you can use the smoothed predictions for visualization or further analysis
#display(smooth_smp_FFN)

# %%
ax = plt.gca()
smp3_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp3_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp3_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#FFD700', ax=ax,label="FFN")
smp3.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/Leave_One_Out_Sample_1.jpg',dpi=300)
plt.show()
