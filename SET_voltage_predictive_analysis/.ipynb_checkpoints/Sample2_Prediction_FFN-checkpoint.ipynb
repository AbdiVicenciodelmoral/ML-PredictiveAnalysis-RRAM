# %%
import pandas as pd
import numpy as np
import nbimporter
from MLModels import mlModels
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
#display(setVoltageDf)

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp2 = setVoltageDf.loc['Sample_2']
smp2_X = smp2.drop('Set_voltage_kde',axis=1)
smp2_y = smp2['Set_voltage_kde']
display(smp2_X)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# ...                           ...                  ...
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# ...                            ...                        ...
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
#
#           Top electrode material  SET Voltage
# Sample
# Sample_2                       2         0.00
# Sample_2                       2         0.01
# Sample_2                       2         0.02
# Sample_2                       2         0.03
# Sample_2                       2         0.04
# ...                          ...          ...
# Sample_2                       2         9.96
# Sample_2                       2         9.97
# Sample_2                       2         9.98
# Sample_2                       2         9.99
# Sample_2                       2        10.00
#
# [1001 rows x 6 columns]

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_2')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_2'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
reg_Models = mlModels()
reg_Models.runModels(X,y,grid_search=False)
# Out:
# Random Forest Regression Mean squared error: 0.00000
# Coefficient of determination: 0.99997
#
#
# Adaboost Regression Mean squared error: 0.00397
# Coefficient of determination: 0.71574

# %%
smp2_pred_ada = smp2_X.copy()
smp2_pred_ada['Set_voltage_kde'] = reg_Models.newSample(smp2_X,'ada')
#smp2_pred_ada
# Out:
# Ada Boost:  [0.1036936  0.1036936  0.1036936  ... 0.03115878 0.03115878 0.03115878]

# %%
smp2_pred_rfr = smp2_X.copy()
smp2_pred_rfr['Set_voltage_kde'] = reg_Models.newSample(smp2_X,'rfr')
#smp2_pred_rfr
# Out:
# Random Forest:  [0.05544985 0.05570111 0.05615467 ... 0.00369286 0.00367812 0.00366454]

# %%
# Load the dataframes

setVoltageDf =  pd.read_csv('process_data/setValues_KDE.csv')

setVoltageDf.set_index('Sample', inplace=True)
setVoltageDf = setVoltageDf.drop(index='Sample_2')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_2'
if s_idx in idx:
    raise ValueError('Sample in Training set')
display(setVoltageDf)

X_train = setVoltageDf.drop('Set_voltage_kde',axis=1)
y_train = setVoltageDf['Set_voltage_kde']

# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1500         
}

model = NeuralNet(X_scaled,y_train,parameters).to(device)
model.train_model()
scaled_smp2_X = standard_scaler.transform(smp2_X)
smp2_pred_FFN = model.testSample(scaled_smp2_X,smp2_X)
display(smp2_pred_FFN)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_1                       2         0.00     5.502315e-02
# Sample_1                       2         0.01     5.566740e-02
# Sample_1                       2         0.02     5.631634e-02
# Sample_1                       2         0.03     5.696996e-02
# Sample_1                       2         0.04     5.762824e-02
# ...                          ...          ...              ...
# Sample_8                       2         9.96     8.278972e-21
# Sample_8                       2         9.97     6.375870e-21
# Sample_8                       2         9.98     4.906279e-21
# Sample_8                       2         9.99     3.772374e-21
# Sample_8                       2        10.00     2.898191e-21
#
# [7007 rows x 7 columns]
# Epoch [100/1500], Loss: 0.0035, R-squared: 0.7407, MAPE: 1547563853.9517%, RMSE: 0.0590, Explained Variance Score: 0.7407
# Epoch [200/1500], Loss: 0.0016, R-squared: 0.8843, MAPE: 1226638944.0029%, RMSE: 0.0394, Explained Variance Score: 0.8844
# Epoch [300/1500], Loss: 0.0011, R-squared: 0.9191, MAPE: 1200802783.0523%, RMSE: 0.0329, Explained Variance Score: 0.9191
# Epoch [400/1500], Loss: 0.0008, R-squared: 0.9388, MAPE: 1124268183.0289%, RMSE: 0.0286, Explained Variance Score: 0.9389
# Epoch [500/1500], Loss: 0.0007, R-squared: 0.9488, MAPE: 992076040.7922%, RMSE: 0.0262, Explained Variance Score: 0.9492
# Epoch [600/1500], Loss: 0.0006, R-squared: 0.9549, MAPE: 1005875008.7298%, RMSE: 0.0246, Explained Variance Score: 0.9549
# Epoch [700/1500], Loss: 0.0006, R-squared: 0.9563, MAPE: 940529614.8300%, RMSE: 0.0242, Explained Variance Score: 0.9563
# Epoch [800/1500], Loss: 0.0006, R-squared: 0.9578, MAPE: 953652777.5796%, RMSE: 0.0238, Explained Variance Score: 0.9578
# Epoch [900/1500], Loss: 0.0005, R-squared: 0.9638, MAPE: 916604545.8912%, RMSE: 0.0220, Explained Variance Score: 0.9638
# Epoch [1000/1500], Loss: 0.0005, R-squared: 0.9663, MAPE: 888871491.1871%, RMSE: 0.0212, Explained Variance Score: 0.9664
# Epoch [1100/1500], Loss: 0.0004, R-squared: 0.9704, MAPE: 846030568.0349%, RMSE: 0.0199, Explained Variance Score: 0.9704
# Epoch [1200/1500], Loss: 0.0004, R-squared: 0.9695, MAPE: 851624715.3644%, RMSE: 0.0202, Explained Variance Score: 0.9696
# Epoch [1300/1500], Loss: 0.0004, R-squared: 0.9699, MAPE: 847973644.0557%, RMSE: 0.0201, Explained Variance Score: 0.9701
# Epoch [1400/1500], Loss: 0.0004, R-squared: 0.9695, MAPE: 876723191.4518%, RMSE: 0.0202, Explained Variance Score: 0.9695
# Epoch [1500/1500], Loss: 0.0004, R-squared: 0.9715, MAPE: 913816570.2759%, RMSE: 0.0195, Explained Variance Score: 0.9716
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            896
# ├─LeakyReLU: 1-2                         --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            16,512
# ├─LeakyReLU: 1-5                         --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            16,512
# ├─LeakyReLU: 1-8                         --
# ├─Dropout: 1-9                           --
# ├─Linear: 1-10                           129
# =================================================================
# Total params: 34,049
# Trainable params: 34,049
# Non-trainable params: 0
# =================================================================
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# ...                           ...                  ...
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# ...                            ...                        ...
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_2                       2         0.00         0.071635
# Sample_2                       2         0.01         0.072194
# Sample_2                       2         0.02         0.072749
# Sample_2                       2         0.03         0.073296
# Sample_2                       2         0.04         0.073838
# ...                          ...          ...              ...
# Sample_2                       2         9.96         0.008816
# Sample_2                       2         9.97         0.008781
# Sample_2                       2         9.98         0.008745
# Sample_2                       2         9.99         0.008710
# Sample_2                       2        10.00         0.008675
#
# [1001 rows x 7 columns]

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
def moving_average(data, window_size):
    ma = np.zeros(len(data))
    for i in range(window_size, len(data) + 1):
        ma[i - 1] = np.mean(data[i - window_size:i])
    return ma

# Set the window size for the moving average
window_size = 4

# Calculate the moving average of the predictions

smooth_smp_FFN = smp2_pred_FFN.copy()
smooth_smp_FFN['Set_voltage_kde'] = moving_average(smp2_pred_FFN['Set_voltage_kde'], window_size)

# Now you can use the smoothed predictions for visualization or further analysis
#display(smooth_smp_FFN)

# %%
ax = plt.gca()
smp2_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost", linestyle=':')
smp2_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="Random Forest", linestyle='-.')
smp2_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="FFN", linestyle='--')
smp2.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
#smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample B')
plt.tight_layout()
plt.savefig('Figures/Leave_One_Out_Sample_2.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp2_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp2.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/ADA_Sample_2.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp2_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp2.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/RFR_Sample_2.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp2_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
smp2.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
plt.legend(prop={'size': 16})
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample B')
plt.tight_layout()
plt.savefig('Figures/FFN_Sample_2.jpg',dpi=300)
plt.show()

# %%
from frechetdist import frdist
s_rfr = np.array(smp2_pred_rfr['Set_voltage_kde'].values).reshape(-1,1)
s_ada = np.array(smp2_pred_ada['Set_voltage_kde'].values).reshape(-1,1)
s_true = np.array(smp2['Set_voltage_kde'].values).reshape(-1,1)
s_FFN = np.array(smp2_pred_FFN['Set_voltage_kde'].values).reshape(-1,1)

print("Frechet distance Ada:",frdist(s_ada,s_true))
print("Frechet distance RFR:",frdist(s_rfr,s_true))
print("Frechet distance FFN:",frdist(s_FFN,s_true))
# Out:
# Frechet distance Ada: 0.10185969834386649
# Frechet distance RFR: 0.0473491621116259
# Frechet distance FFN: 0.055332617403392154

# %%
from scipy.stats import wasserstein_distance
s_true = np.array(smp2['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_FFN = np.array(smp2_pred_FFN['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_ada = np.array(smp2_pred_ada['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_rfr = np.array(smp2_pred_rfr['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()

# Calculate Wasserstein distance
print("Wasserstein distance Ada:", wasserstein_distance(s_ada, s_true))
print("Wasserstein distance rfr:", wasserstein_distance(s_rfr, s_true))
print("Wasserstein distance FFN:", wasserstein_distance(s_FFN, s_true))
# Out:
# Wasserstein distance Ada: 0.02921017063292749
# Wasserstein distance rfr: 0.019557074200746233
# Wasserstein distance FFN: 0.01762173059885499
