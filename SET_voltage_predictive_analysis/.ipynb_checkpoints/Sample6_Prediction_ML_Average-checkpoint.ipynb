# %%
import pandas as pd
import numpy as np
import nbimporter
from MLModels import mlModels
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
#display(setVoltageDf)

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp5 = setVoltageDf.loc['Sample_5']
smp5_X = smp5.drop('Set_voltage_kde',axis=1)
smp5_y = smp5['Set_voltage_kde']
display(smp5_X)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
#
#           Top electrode material  SET Voltage
# Sample
# Sample_5                       2          0.0
# Sample_5                       2          0.2
# Sample_5                       2          0.4
# Sample_5                       2          0.6
# Sample_5                       2          0.8
# Sample_5                       2          1.0
# Sample_5                       2          1.2
# Sample_5                       2          1.4
# Sample_5                       2          1.6
# Sample_5                       2          1.8
# Sample_5                       2          2.0
# Sample_5                       2          2.2
# Sample_5                       2          2.4
# Sample_5                       2          2.6
# Sample_5                       2          2.8
# Sample_5                       2          3.0
# Sample_5                       2          3.2
# Sample_5                       2          3.4
# Sample_5                       2          3.6
# Sample_5                       2          3.8
# Sample_5                       2          4.0
# Sample_5                       2          4.2
# Sample_5                       2          4.4
# Sample_5                       2          4.6
# Sample_5                       2          4.8
# Sample_5                       2          5.0
# Sample_5                       2          5.2
# Sample_5                       2          5.4
# Sample_5                       2          5.6
# Sample_5                       2          5.8
# Sample_5                       2          6.0
# Sample_5                       2          6.2
# Sample_5                       2          6.4
# Sample_5                       2          6.6
# Sample_5                       2          6.8
# Sample_5                       2          7.0
# Sample_5                       2          7.2
# Sample_5                       2          7.4
# Sample_5                       2          7.6
# Sample_5                       2          7.8
# Sample_5                       2          8.0
# Sample_5                       2          8.2
# Sample_5                       2          8.4
# Sample_5                       2          8.6
# Sample_5                       2          8.8
# Sample_5                       2          9.0
# Sample_5                       2          9.2
# Sample_5                       2          9.4
# Sample_5                       2          9.6
# Sample_5                       2          9.8
# Sample_5                       2         10.0

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_5')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_5'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
reg_Models = mlModels()
reg_Models.runModels(X,y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
#
#
# Random Forest Regression Mean squared error: 0.00001
# Coefficient of determination: 0.99533
#
#
# Adaboost Regression Mean squared error: 0.00254
# Coefficient of determination: -0.74419

# %%
smp5_pred_ada = smp5_X.copy()
smp5_pred_ada['Set_voltage_kde'] = reg_Models.newSample(smp5_X,'ada')
#smp5_pred_ada
# Out:
# Ada Boost:  [0.05765709 0.05765709 0.14751127 0.11125866 0.12725671 0.12725671
#  0.18510852 0.18510852 0.18510852 0.19416215 0.20489009 0.21229611
#  0.2158395  0.2158395  0.21180889 0.20965412 0.20965412 0.19416215
#  0.17774955 0.16623167 0.16406554 0.14918337 0.14413839 0.12576841
#  0.12234962 0.12073674 0.09277984 0.07933844 0.07296406 0.06885316
#  0.0599757  0.0599757  0.0599757  0.0599757  0.0599757  0.0599757
#  0.0599757  0.0599757  0.0599757  0.0599757  0.0599757  0.0599757
#  0.0599757  0.0599757  0.0599757  0.0599757  0.0599757  0.0599757
#  0.0599757  0.0599757  0.0599757 ]

# %%
smp5_pred_rfr = smp5_X.copy()
smp5_pred_rfr['Set_voltage_kde'] = reg_Models.newSample(smp5_X,'rfr')
#smp5_pred_rfr
# Out:
# Random Forest:  [0.08740918 0.09963407 0.12447239 0.15526965 0.15717385 0.16747916
#  0.18222537 0.1843372  0.18290211 0.17698434 0.17980487 0.1760095
#  0.17799587 0.18159682 0.18788939 0.19688258 0.19755523 0.19131571
#  0.19079974 0.19556496 0.20321199 0.21206721 0.22264052 0.2341336
#  0.21330164 0.16703463 0.09929667 0.06066977 0.04236053 0.02938513
#  0.02821602 0.02412601 0.02262797 0.01890557 0.01620856 0.01506532
#  0.01451571 0.0181736  0.02150579 0.02964522 0.03316215 0.03543656
#  0.03479991 0.02934028 0.02267957 0.01637077 0.0105907  0.00739198
#  0.00533331 0.00549959 0.00732075]

# %%
# Load the dataframes

setVoltageDf =  pd.read_csv('process_data/setVoltage_KDE.csv')

setVoltageDf.set_index('Sample', inplace=True)
setVoltageDf = setVoltageDf.drop(index='Sample_5')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_5'
if s_idx in idx:
    raise ValueError('Sample in Training set')
display(setVoltageDf)

X_train = setVoltageDf.drop('Set_voltage_kde',axis=1)
y_train = setVoltageDf['Set_voltage_kde']

# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1000         
}

model = NeuralNet(X_scaled,y_train,parameters).to(device)
model.train_model()
scaled_smp5_X = standard_scaler.transform(smp5_X)
smp5_pred_FFN = model.testSample(scaled_smp5_X,smp5_X)
display(smp5_pred_FFN)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_2                       2         1.40         0.101198
# Sample_2                       2         5.00         0.111477
# Sample_2                       2         0.77         0.075984
# Sample_2                       2         1.50         0.103259
# Sample_2                       2         2.92         0.206484
# ...                          ...          ...              ...
# Sample_8                       2         3.20         0.271727
# Sample_8                       2         4.70         0.272732
# Sample_8                       2         3.06         0.268237
# Sample_8                       2         4.74         0.271047
# Sample_8                       2         2.64         0.210634
#
# [780 rows x 7 columns]
# Epoch [10/1000], Loss: 0.0421, R-squared: -0.6019, MAPE: 152.9836%
# Epoch [20/1000], Loss: 0.0315, R-squared: -0.1993, MAPE: 137.7581%
# Epoch [30/1000], Loss: 0.0240, R-squared: 0.0855, MAPE: 116.0891%
# Epoch [40/1000], Loss: 0.0200, R-squared: 0.2385, MAPE: 90.4393%
# Epoch [50/1000], Loss: 0.0176, R-squared: 0.3312, MAPE: 75.0656%
# Epoch [60/1000], Loss: 0.0156, R-squared: 0.4056, MAPE: 80.1507%
# Epoch [70/1000], Loss: 0.0136, R-squared: 0.4812, MAPE: 72.6672%
# Epoch [80/1000], Loss: 0.0130, R-squared: 0.5035, MAPE: 70.7246%
# Epoch [90/1000], Loss: 0.0132, R-squared: 0.4961, MAPE: 62.2184%
# Epoch [100/1000], Loss: 0.0130, R-squared: 0.5046, MAPE: 65.9774%
# Epoch [110/1000], Loss: 0.0113, R-squared: 0.5715, MAPE: 62.7913%
# Epoch [120/1000], Loss: 0.0109, R-squared: 0.5847, MAPE: 54.7012%
# Epoch [130/1000], Loss: 0.0106, R-squared: 0.5982, MAPE: 57.8293%
# Epoch [140/1000], Loss: 0.0098, R-squared: 0.6281, MAPE: 52.1842%
# Epoch [150/1000], Loss: 0.0098, R-squared: 0.6262, MAPE: 52.1930%
# Epoch [160/1000], Loss: 0.0091, R-squared: 0.6523, MAPE: 51.1696%
# Epoch [170/1000], Loss: 0.0081, R-squared: 0.6898, MAPE: 46.0486%
# Epoch [180/1000], Loss: 0.0080, R-squared: 0.6949, MAPE: 47.8552%
# Epoch [190/1000], Loss: 0.0081, R-squared: 0.6934, MAPE: 41.6161%
# Epoch [200/1000], Loss: 0.0077, R-squared: 0.7069, MAPE: 43.1587%
# Epoch [210/1000], Loss: 0.0076, R-squared: 0.7093, MAPE: 47.2537%
# Epoch [220/1000], Loss: 0.0072, R-squared: 0.7251, MAPE: 44.2939%
# Epoch [230/1000], Loss: 0.0070, R-squared: 0.7318, MAPE: 38.3651%
# Epoch [240/1000], Loss: 0.0073, R-squared: 0.7219, MAPE: 41.7925%
# Epoch [250/1000], Loss: 0.0061, R-squared: 0.7686, MAPE: 39.2422%
# Epoch [260/1000], Loss: 0.0067, R-squared: 0.7442, MAPE: 38.8806%
# Epoch [270/1000], Loss: 0.0059, R-squared: 0.7742, MAPE: 38.3637%
# Epoch [280/1000], Loss: 0.0055, R-squared: 0.7906, MAPE: 39.1507%
# Epoch [290/1000], Loss: 0.0055, R-squared: 0.7905, MAPE: 36.5746%
# Epoch [300/1000], Loss: 0.0056, R-squared: 0.7851, MAPE: 40.4100%
# Epoch [310/1000], Loss: 0.0061, R-squared: 0.7670, MAPE: 35.0777%
# Epoch [320/1000], Loss: 0.0049, R-squared: 0.8124, MAPE: 34.9420%
# Epoch [330/1000], Loss: 0.0050, R-squared: 0.8082, MAPE: 34.9056%
# Epoch [340/1000], Loss: 0.0050, R-squared: 0.8086, MAPE: 37.0944%
# Epoch [350/1000], Loss: 0.0052, R-squared: 0.8009, MAPE: 35.5674%
# Epoch [360/1000], Loss: 0.0047, R-squared: 0.8203, MAPE: 31.8540%
# Epoch [370/1000], Loss: 0.0050, R-squared: 0.8085, MAPE: 33.4894%
# Epoch [380/1000], Loss: 0.0043, R-squared: 0.8380, MAPE: 32.8768%
# Epoch [390/1000], Loss: 0.0048, R-squared: 0.8187, MAPE: 31.7562%
# Epoch [400/1000], Loss: 0.0049, R-squared: 0.8138, MAPE: 32.6845%
# Epoch [410/1000], Loss: 0.0044, R-squared: 0.8309, MAPE: 33.1497%
# Epoch [420/1000], Loss: 0.0041, R-squared: 0.8443, MAPE: 29.1954%
# Epoch [430/1000], Loss: 0.0039, R-squared: 0.8515, MAPE: 32.7530%
# Epoch [440/1000], Loss: 0.0040, R-squared: 0.8480, MAPE: 32.8822%
# Epoch [450/1000], Loss: 0.0038, R-squared: 0.8536, MAPE: 27.9995%
# Epoch [460/1000], Loss: 0.0038, R-squared: 0.8561, MAPE: 28.0041%
# Epoch [470/1000], Loss: 0.0037, R-squared: 0.8581, MAPE: 29.7977%
# Epoch [480/1000], Loss: 0.0038, R-squared: 0.8569, MAPE: 30.3062%
# Epoch [490/1000], Loss: 0.0037, R-squared: 0.8590, MAPE: 28.7271%
# Epoch [500/1000], Loss: 0.0036, R-squared: 0.8620, MAPE: 32.2649%
# Epoch [510/1000], Loss: 0.0036, R-squared: 0.8639, MAPE: 28.5543%
# Epoch [520/1000], Loss: 0.0036, R-squared: 0.8639, MAPE: 32.4162%
# Epoch [530/1000], Loss: 0.0035, R-squared: 0.8674, MAPE: 28.0470%
# Epoch [540/1000], Loss: 0.0030, R-squared: 0.8846, MAPE: 29.0813%
# Epoch [550/1000], Loss: 0.0034, R-squared: 0.8691, MAPE: 33.1113%
# Epoch [560/1000], Loss: 0.0034, R-squared: 0.8724, MAPE: 33.7285%
# Epoch [570/1000], Loss: 0.0033, R-squared: 0.8729, MAPE: 30.5060%
# Epoch [580/1000], Loss: 0.0032, R-squared: 0.8771, MAPE: 28.4727%
# Epoch [590/1000], Loss: 0.0030, R-squared: 0.8869, MAPE: 31.8102%
# Epoch [600/1000], Loss: 0.0029, R-squared: 0.8892, MAPE: 27.1028%
# Epoch [610/1000], Loss: 0.0032, R-squared: 0.8772, MAPE: 27.4477%
# Epoch [620/1000], Loss: 0.0031, R-squared: 0.8825, MAPE: 34.2940%
# Epoch [630/1000], Loss: 0.0034, R-squared: 0.8689, MAPE: 30.0331%
# Epoch [640/1000], Loss: 0.0029, R-squared: 0.8877, MAPE: 28.3231%
# Epoch [650/1000], Loss: 0.0028, R-squared: 0.8931, MAPE: 29.8824%
# Epoch [660/1000], Loss: 0.0028, R-squared: 0.8916, MAPE: 26.2668%
# Epoch [670/1000], Loss: 0.0026, R-squared: 0.9011, MAPE: 28.0292%
# Epoch [680/1000], Loss: 0.0026, R-squared: 0.9012, MAPE: 27.9352%
# Epoch [690/1000], Loss: 0.0029, R-squared: 0.8883, MAPE: 27.3496%
# Epoch [700/1000], Loss: 0.0029, R-squared: 0.8908, MAPE: 28.7089%
# Epoch [710/1000], Loss: 0.0029, R-squared: 0.8883, MAPE: 25.8233%
# Epoch [720/1000], Loss: 0.0025, R-squared: 0.9048, MAPE: 26.7821%
# Epoch [730/1000], Loss: 0.0027, R-squared: 0.8965, MAPE: 26.0500%
# Epoch [740/1000], Loss: 0.0026, R-squared: 0.9005, MAPE: 27.4936%
# Epoch [750/1000], Loss: 0.0028, R-squared: 0.8921, MAPE: 30.1592%
# Epoch [760/1000], Loss: 0.0025, R-squared: 0.9030, MAPE: 30.5425%
# Epoch [770/1000], Loss: 0.0025, R-squared: 0.9036, MAPE: 26.8060%
# Epoch [780/1000], Loss: 0.0027, R-squared: 0.8981, MAPE: 29.3193%
# Epoch [790/1000], Loss: 0.0025, R-squared: 0.9046, MAPE: 25.3950%
# Epoch [800/1000], Loss: 0.0029, R-squared: 0.8906, MAPE: 28.9364%
# Epoch [810/1000], Loss: 0.0023, R-squared: 0.9136, MAPE: 26.6944%
# Epoch [820/1000], Loss: 0.0022, R-squared: 0.9154, MAPE: 24.9158%
# Epoch [830/1000], Loss: 0.0023, R-squared: 0.9139, MAPE: 29.7729%
# Epoch [840/1000], Loss: 0.0025, R-squared: 0.9065, MAPE: 29.4061%
# Epoch [850/1000], Loss: 0.0023, R-squared: 0.9120, MAPE: 27.1945%
# Epoch [860/1000], Loss: 0.0025, R-squared: 0.9048, MAPE: 31.0362%
# Epoch [870/1000], Loss: 0.0025, R-squared: 0.9048, MAPE: 28.3568%
# Epoch [880/1000], Loss: 0.0023, R-squared: 0.9124, MAPE: 28.3634%
# Epoch [890/1000], Loss: 0.0022, R-squared: 0.9162, MAPE: 25.4193%
# Epoch [900/1000], Loss: 0.0024, R-squared: 0.9092, MAPE: 29.4958%
# Epoch [910/1000], Loss: 0.0023, R-squared: 0.9119, MAPE: 26.9744%
# Epoch [920/1000], Loss: 0.0022, R-squared: 0.9148, MAPE: 27.4958%
# Epoch [930/1000], Loss: 0.0021, R-squared: 0.9214, MAPE: 24.5996%
# Epoch [940/1000], Loss: 0.0025, R-squared: 0.9044, MAPE: 26.1726%
# Epoch [950/1000], Loss: 0.0023, R-squared: 0.9111, MAPE: 25.1888%
# Epoch [960/1000], Loss: 0.0024, R-squared: 0.9104, MAPE: 29.5817%
# Epoch [970/1000], Loss: 0.0022, R-squared: 0.9181, MAPE: 24.2534%
# Epoch [980/1000], Loss: 0.0021, R-squared: 0.9216, MAPE: 26.4142%
# Epoch [990/1000], Loss: 0.0025, R-squared: 0.9041, MAPE: 30.6461%
# Epoch [1000/1000], Loss: 0.0023, R-squared: 0.9131, MAPE: 26.2065%
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            896
# ├─LeakyReLU: 1-2                         --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            16,512
# ├─LeakyReLU: 1-5                         --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            129
# =================================================================
# Total params: 17,537
# Trainable params: 17,537
# Non-trainable params: 0
# =================================================================
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_5                       2          0.0         0.204539
# Sample_5                       2          0.2         0.212310
# Sample_5                       2          0.4         0.219625
# Sample_5                       2          0.6         0.224720
# Sample_5                       2          0.8         0.227865
# Sample_5                       2          1.0         0.231053
# Sample_5                       2          1.2         0.231923
# Sample_5                       2          1.4         0.232285
# Sample_5                       2          1.6         0.232845
# Sample_5                       2          1.8         0.228945
# Sample_5                       2          2.0         0.220081
# Sample_5                       2          2.2         0.208851
# Sample_5                       2          2.4         0.191076
# Sample_5                       2          2.6         0.176369
# Sample_5                       2          2.8         0.163624
# Sample_5                       2          3.0         0.151060
# Sample_5                       2          3.2         0.135030
# Sample_5                       2          3.4         0.121632
# Sample_5                       2          3.6         0.114970
# Sample_5                       2          3.8         0.110547
# Sample_5                       2          4.0         0.106746
# Sample_5                       2          4.2         0.102980
# Sample_5                       2          4.4         0.099427
# Sample_5                       2          4.6         0.096082
# Sample_5                       2          4.8         0.092819
# Sample_5                       2          5.0         0.089610
# Sample_5                       2          5.2         0.086509
# Sample_5                       2          5.4         0.083408
# Sample_5                       2          5.6         0.080676
# Sample_5                       2          5.8         0.078030
# Sample_5                       2          6.0         0.075490
# Sample_5                       2          6.2         0.073187
# Sample_5                       2          6.4         0.071152
# Sample_5                       2          6.6         0.069142
# Sample_5                       2          6.8         0.067133
# Sample_5                       2          7.0         0.065124
# Sample_5                       2          7.2         0.063203
# Sample_5                       2          7.4         0.061350
# Sample_5                       2          7.6         0.059491
# Sample_5                       2          7.8         0.057835
# Sample_5                       2          8.0         0.056660
# Sample_5                       2          8.2         0.055487
# Sample_5                       2          8.4         0.054314
# Sample_5                       2          8.6         0.053141
# Sample_5                       2          8.8         0.051966
# Sample_5                       2          9.0         0.050773
# Sample_5                       2          9.2         0.049580
# Sample_5                       2          9.4         0.048388
# Sample_5                       2          9.6         0.047195
# Sample_5                       2          9.8         0.046003
# Sample_5                       2         10.0         0.044810

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
def moving_average(data, window_size):
    ma = np.zeros(len(data))
    for i in range(window_size, len(data) + 1):
        ma[i - 1] = np.mean(data[i - window_size:i])
    return ma

# Set the window size for the moving average
window_size = 4

# Calculate the moving average of the predictions

smooth_smp_FFN = smp5_pred_FFN.copy()
smooth_smp_FFN['Set_voltage_kde'] = moving_average(smp5_pred_FFN['Set_voltage_kde'], window_size)

# Now you can use the smoothed predictions for visualization or further analysis
#display(smooth_smp_FFN)

# %%
ax = plt.gca()
smp5_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp5_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp5_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#FFD700', ax=ax,label="FFN")
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/Leave_One_Out_Sample_1.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp5_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/ADA_Sample_5.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp5_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/RFR_Sample_5.jpg',dpi=300)
plt.show()
