# %%
import pandas as pd
import numpy as np
import nbimporter
from getKDE import getKDE
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
display(setVoltageDf)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_1                       2         0.00     5.502315e-02
# Sample_1                       2         0.01     5.566740e-02
# Sample_1                       2         0.02     5.631634e-02
# Sample_1                       2         0.03     5.696996e-02
# Sample_1                       2         0.04     5.762824e-02
# ...                          ...          ...              ...
# Sample_8                       2         9.96     8.278972e-21
# Sample_8                       2         9.97     6.375870e-21
# Sample_8                       2         9.98     4.906279e-21
# Sample_8                       2         9.99     3.772374e-21
# Sample_8                       2        10.00     2.898191e-21
#
# [8008 rows x 7 columns]

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp1 = setVoltageDf.loc['Sample_1']
smp1_X = smp1.drop('Set_voltage_kde',axis=1)
smp1_y = setVoltageDf['Set_voltage_kde']
display(smp1)
smp1.to_csv('smp1.csv')
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...                            ...                        ...
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_1                       2         0.00         0.055023
# Sample_1                       2         0.01         0.055667
# Sample_1                       2         0.02         0.056316
# Sample_1                       2         0.03         0.056970
# Sample_1                       2         0.04         0.057628
# ...                          ...          ...              ...
# Sample_1                       2         9.96         0.003346
# Sample_1                       2         9.97         0.003329
# Sample_1                       2         9.98         0.003312
# Sample_1                       2         9.99         0.003295
# Sample_1                       2        10.00         0.003277
#
# [1001 rows x 7 columns]

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_1')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_1'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1500         
}

ffn_predictions = []
window_size = 4
for _ in range(100):
    model = NeuralNet(X_scaled,y_train,parameters).to(device)
    model.train_model()
    scaled_smp1_X = standard_scaler.transform(smp1_X)
    smp1_pred_FFN = model.testSample(scaled_smp1_X)
    ffn_predictions.append(smp1_pred_FFN)
    

def average_line(data,model_name,window_size):
    
    # Calculate the cumulative sum of values at each index
    cumulative_sum = np.sum(data, axis=0)
    
    # Calculate the average by dividing the cumulative sum by the number of arrays
    average_line = cumulative_sum / len(data)

    # Plotting the individual lines
    for line in data:
        plt.plot(line)
    
    #Calculate ROlling Average
    """rolling_avg = np.zeros(len(average_line))
    for i in range(window_size, len(average_line) + 1):
        rolling_avg[i - 1] = np.mean(average_line[i - window_size:i])"""

    # Plotting the average line
    plt.plot(average_line, linewidth=2, color='red', label=model_name+'_Average')

    # Customize the plot
    plt.xlabel('X axis')
    plt.ylabel('Y axis')
    plt.legend()

    # Display the plot
    plt.show()
    plt.savefig('Figures/AVG'+model_name+'_Sample_1.jpg',dpi=300)
    return average_line


smp1_pred_ffn['Set_voltage_kde'] = average_line(ffn_predictions,"FFN",window_size)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_2                       2         0.00     1.630193e-02
# Sample_2                       2         0.01     1.682501e-02
# Sample_2                       2         0.02     1.735914e-02
# Sample_2                       2         0.03     1.790434e-02
# Sample_2                       2         0.04     1.846059e-02
# ...                          ...          ...              ...
# Sample_8                       2         9.96     8.278972e-21
# Sample_8                       2         9.97     6.375870e-21
# Sample_8                       2         9.98     4.906279e-21
# Sample_8                       2         9.99     3.772374e-21
# Sample_8                       2        10.00     2.898191e-21
#
# [7007 rows x 7 columns]
# Epoch [100/1500], Loss: 0.0023, R-squared: 0.8317, MAPE: 1494101552.1713%, RMSE: 0.0475, Explained Variance Score: 0.8318
# Epoch [200/1500], Loss: 0.0010, R-squared: 0.9262, MAPE: 1346643359.0241%, RMSE: 0.0315, Explained Variance Score: 0.9263
# Epoch [300/1500], Loss: 0.0008, R-squared: 0.9417, MAPE: 1180219433.0073%, RMSE: 0.0280, Explained Variance Score: 0.9418
# Epoch [400/1500], Loss: 0.0006, R-squared: 0.9550, MAPE: 1091207110.5736%, RMSE: 0.0246, Explained Variance Score: 0.9550
# Epoch [500/1500], Loss: 0.0005, R-squared: 0.9596, MAPE: 1045618471.6853%, RMSE: 0.0233, Explained Variance Score: 0.9596
# Epoch [600/1500], Loss: 0.0005, R-squared: 0.9642, MAPE: 936692660.0605%, RMSE: 0.0219, Explained Variance Score: 0.9643
# Epoch [700/1500], Loss: 0.0004, R-squared: 0.9666, MAPE: 951080678.8325%, RMSE: 0.0212, Explained Variance Score: 0.9666
# Epoch [800/1500], Loss: 0.0004, R-squared: 0.9706, MAPE: 984294928.3241%, RMSE: 0.0198, Explained Variance Score: 0.9707
# Epoch [900/1500], Loss: 0.0004, R-squared: 0.9710, MAPE: 915769724.7245%, RMSE: 0.0197, Explained Variance Score: 0.9710
# Epoch [1000/1500], Loss: 0.0004, R-squared: 0.9716, MAPE: 860221303.9777%, RMSE: 0.0195, Explained Variance Score: 0.9717
# Epoch [1100/1500], Loss: 0.0004, R-squared: 0.9736, MAPE: 878519954.5574%, RMSE: 0.0188, Explained Variance Score: 0.9738
# Epoch [1200/1500], Loss: 0.0003, R-squared: 0.9740, MAPE: 877417017.4212%, RMSE: 0.0187, Explained Variance Score: 0.9740
# Epoch [1300/1500], Loss: 0.0003, R-squared: 0.9755, MAPE: 887729681.9749%, RMSE: 0.0181, Explained Variance Score: 0.9757
# Epoch [1400/1500], Loss: 0.0003, R-squared: 0.9744, MAPE: 965787273.5081%, RMSE: 0.0185, Explained Variance Score: 0.9745
# Epoch [1500/1500], Loss: 0.0003, R-squared: 0.9765, MAPE: 964083309.5441%, RMSE: 0.0178, Explained Variance Score: 0.9768
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            896
# ├─LeakyReLU: 1-2                         --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            16,512
# ├─LeakyReLU: 1-5                         --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            16,512
# ├─LeakyReLU: 1-8                         --
# ├─Dropout: 1-9                           --
# ├─Linear: 1-10                           129
# =================================================================
# Total params: 34,049
# Trainable params: 34,049
# Non-trainable params: 0
# =================================================================
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...                            ...                        ...
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_1                       2         0.00         0.040452
# Sample_1                       2         0.01         0.040958
# Sample_1                       2         0.02         0.041509
# Sample_1                       2         0.03         0.042063
# Sample_1                       2         0.04         0.042635
# ...                          ...          ...              ...
# Sample_1                       2         9.96         0.002923
# Sample_1                       2         9.97         0.002867
# Sample_1                       2         9.98         0.002810
# Sample_1                       2         9.99         0.002754
# Sample_1                       2        10.00         0.002698
#
# [1001 rows x 7 columns]

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
smp1_pred_FFN
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...                            ...                        ...
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_1                       2         0.00         0.040452
# Sample_1                       2         0.01         0.040958
# Sample_1                       2         0.02         0.041509
# Sample_1                       2         0.03         0.042063
# Sample_1                       2         0.04         0.042635
# ...                          ...          ...              ...
# Sample_1                       2         9.96         0.002923
# Sample_1                       2         9.97         0.002867
# Sample_1                       2         9.98         0.002810
# Sample_1                       2         9.99         0.002754
# Sample_1                       2        10.00         0.002698
#
# [1001 rows x 7 columns]

# %%
ax = plt.gca()
smp1_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="FFN", linestyle='--')
smp1.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample A')
plt.tight_layout()
plt.savefig('Figures/Leave_One_Out_Sample_1.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp1_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
smp1.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
#smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#FFD700', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
plt.legend(prop={'size': 16})
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample A')
plt.tight_layout()
plt.savefig('Figures/FFN_Sample_1.jpg',dpi=300)
plt.show()

# %%
from frechetdist import frdist
s_true = np.array(smp1['Set_voltage_kde'].values).reshape(-1,1)
s_FFN = np.array(smp1_pred_FFN['Set_voltage_kde'].values).reshape(-1,1)

print("Frechet distance FFN:",frdist(s_FFN,s_true))
# Out:
# Frechet distance Ada: 0.046607093356413616
# Frechet distance RFR: 0.0883645258274792
# Frechet distance FFN: 0.014570827054641723

# %%
from scipy.stats import wasserstein_distance
s_true = np.array(smp1['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_FFN = np.array(smp1_pred_FFN['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()

# Calculate Wasserstein distance
print("Wasserstein distance FFN:", wasserstein_distance(s_FFN, s_true))
# Out:
# Wasserstein distance Ada: 0.028928966009100734
# Wasserstein distance rfr: 0.03751194948054422
# Wasserstein distance FFN: 0.01126526820879566
