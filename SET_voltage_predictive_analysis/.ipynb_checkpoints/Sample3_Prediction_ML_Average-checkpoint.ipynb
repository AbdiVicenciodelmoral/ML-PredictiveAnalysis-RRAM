# %%
import pandas as pd
import numpy as np
import nbimporter
from MLModels import mlModels
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
#display(setVoltageDf)

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp2 = setVoltageDf.loc['Sample_2']
smp2_X = smp2.drop('Set_voltage_kde',axis=1)
smp2_y = smp2['Set_voltage_kde']
display(smp2_X)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
#
#           Top electrode material  SET Voltage
# Sample
# Sample_2                       2          0.0
# Sample_2                       2          0.2
# Sample_2                       2          0.4
# Sample_2                       2          0.6
# Sample_2                       2          0.8
# Sample_2                       2          1.0
# Sample_2                       2          1.2
# Sample_2                       2          1.4
# Sample_2                       2          1.6
# Sample_2                       2          1.8
# Sample_2                       2          2.0
# Sample_2                       2          2.2
# Sample_2                       2          2.4
# Sample_2                       2          2.6
# Sample_2                       2          2.8
# Sample_2                       2          3.0
# Sample_2                       2          3.2
# Sample_2                       2          3.4
# Sample_2                       2          3.6
# Sample_2                       2          3.8
# Sample_2                       2          4.0
# Sample_2                       2          4.2
# Sample_2                       2          4.4
# Sample_2                       2          4.6
# Sample_2                       2          4.8
# Sample_2                       2          5.0
# Sample_2                       2          5.2
# Sample_2                       2          5.4
# Sample_2                       2          5.6
# Sample_2                       2          5.8
# Sample_2                       2          6.0
# Sample_2                       2          6.2
# Sample_2                       2          6.4
# Sample_2                       2          6.6
# Sample_2                       2          6.8
# Sample_2                       2          7.0
# Sample_2                       2          7.2
# Sample_2                       2          7.4
# Sample_2                       2          7.6
# Sample_2                       2          7.8
# Sample_2                       2          8.0
# Sample_2                       2          8.2
# Sample_2                       2          8.4
# Sample_2                       2          8.6
# Sample_2                       2          8.8
# Sample_2                       2          9.0
# Sample_2                       2          9.2
# Sample_2                       2          9.4
# Sample_2                       2          9.6
# Sample_2                       2          9.8
# Sample_2                       2         10.0

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_2')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_2'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
reg_Models = mlModels()
reg_Models.runModels(X,y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
#
#
# Random Forest Regression Mean squared error: 0.00001
# Coefficient of determination: 0.99542
#
#
# Adaboost Regression Mean squared error: 0.00101
# Coefficient of determination: 0.30278

# %%
smp2_pred_ada = smp2_X.copy()
smp2_pred_ada['Set_voltage_kde'] = reg_Models.newSample(smp2_X,'ada')
#smp2_pred_ada
# Out:
# Ada Boost:  [0.09153913 0.09153913 0.11412014 0.12793934 0.16092881 0.16255118
#  0.187202   0.17241826 0.17241826 0.14955439 0.14955439 0.14955439
#  0.14955439 0.14955439 0.12932416 0.12894115 0.12894115 0.12393206
#  0.12170486 0.12064378 0.10373485 0.09482685 0.09074949 0.09074949
#  0.09074949 0.09074949 0.08496301 0.05311457 0.05128355 0.0447311
#  0.0447311  0.04387764 0.03743747 0.0302559  0.02626986 0.02626986
#  0.02595462 0.02595462 0.02595462 0.02595462 0.02595462 0.02595462
#  0.02595462 0.02595462 0.02595462 0.02595462 0.02595462 0.02595462
#  0.02595462 0.02595462 0.02595462]

# %%
smp2_pred_rfr = smp2_X.copy()
smp2_pred_rfr['Set_voltage_kde'] = reg_Models.newSample(smp2_X,'rfr')
#smp2_pred_rfr
# Out:
# Random Forest:  [0.06026589 0.06834022 0.08603313 0.11070568 0.12365753 0.16241018
#  0.17999664 0.17729948 0.18891517 0.19267782 0.19543887 0.19648235
#  0.19727347 0.19698932 0.19382879 0.19314978 0.19000771 0.18301187
#  0.17870064 0.16820561 0.15647848 0.14821942 0.13504518 0.1267649
#  0.11428281 0.10585131 0.09814742 0.08537465 0.07904489 0.06740548
#  0.06244838 0.05518165 0.04806294 0.0421407  0.03522021 0.02975507
#  0.02579189 0.02408455 0.02377697 0.02366699 0.0237988  0.02296859
#  0.02078615 0.01592773 0.01131295 0.00810021 0.00599084 0.00531317
#  0.00476598 0.00443496 0.00388503]

# %%
# Load the dataframes

setVoltageDf =  pd.read_csv('process_data/setVoltage_KDE.csv')

setVoltageDf.set_index('Sample', inplace=True)
setVoltageDf = setVoltageDf.drop(index='Sample_1')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_1'
if s_idx in idx:
    raise ValueError('Sample in Training set')
display(setVoltageDf)

X_train = setVoltageDf.drop('Set_voltage_kde',axis=1)
y_train = setVoltageDf['Set_voltage_kde']

# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1000         
}

model = NeuralNet(X_scaled,y_train,parameters).to(device)
model.train_model()
scaled_smp2_X = standard_scaler.transform(smp2_X)
smp2_pred_FFN = model.testSample(scaled_smp2_X,smp2_X)
display(smp2_pred_FFN)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_2                       2         1.40         0.101198
# Sample_2                       2         5.00         0.111477
# Sample_2                       2         0.77         0.075984
# Sample_2                       2         1.50         0.103259
# Sample_2                       2         2.92         0.206484
# ...                          ...          ...              ...
# Sample_8                       2         3.20         0.271727
# Sample_8                       2         4.70         0.272732
# Sample_8                       2         3.06         0.268237
# Sample_8                       2         4.74         0.271047
# Sample_8                       2         2.64         0.210634
#
# [780 rows x 7 columns]
# Epoch [10/1000], Loss: 0.0393, R-squared: -0.4973, MAPE: 161.9291%
# Epoch [20/1000], Loss: 0.0282, R-squared: -0.0750, MAPE: 122.4944%
# Epoch [30/1000], Loss: 0.0186, R-squared: 0.2934, MAPE: 81.3278%
# Epoch [730/1000], Loss: 0.0026, R-squared: 0.9005, MAPE: 26.3165%
# Epoch [740/1000], Loss: 0.0030, R-squared: 0.8871, MAPE: 31.5957%
# Epoch [750/1000], Loss: 0.0025, R-squared: 0.9034, MAPE: 26.4449%
# Epoch [760/1000], Loss: 0.0026, R-squared: 0.9004, MAPE: 32.1538%
# Epoch [770/1000], Loss: 0.0024, R-squared: 0.9092, MAPE: 26.7260%
# Epoch [780/1000], Loss: 0.0023, R-squared: 0.9113, MAPE: 24.8009%
# Epoch [790/1000], Loss: 0.0025, R-squared: 0.9047, MAPE: 29.0813%
# Epoch [800/1000], Loss: 0.0022, R-squared: 0.9152, MAPE: 25.8145%
# Epoch [810/1000], Loss: 0.0021, R-squared: 0.9206, MAPE: 28.8690%
# Epoch [820/1000], Loss: 0.0022, R-squared: 0.9171, MAPE: 26.9014%
# Epoch [830/1000], Loss: 0.0026, R-squared: 0.9010, MAPE: 30.4653%
# Epoch [840/1000], Loss: 0.0021, R-squared: 0.9205, MAPE: 26.0084%
# Epoch [850/1000], Loss: 0.0025, R-squared: 0.9063, MAPE: 30.4881%
# Epoch [860/1000], Loss: 0.0027, R-squared: 0.8968, MAPE: 30.6856%
# Epoch [870/1000], Loss: 0.0024, R-squared: 0.9087, MAPE: 26.7856%
# Epoch [880/1000], Loss: 0.0022, R-squared: 0.9156, MAPE: 26.6891%
# Epoch [890/1000], Loss: 0.0023, R-squared: 0.9107, MAPE: 27.6750%
# Epoch [900/1000], Loss: 0.0024, R-squared: 0.9074, MAPE: 31.8568%
# Epoch [910/1000], Loss: 0.0024, R-squared: 0.9095, MAPE: 27.0888%
# Epoch [920/1000], Loss: 0.0024, R-squared: 0.9070, MAPE: 30.7081%
# Epoch [930/1000], Loss: 0.0023, R-squared: 0.9119, MAPE: 29.4088%
# Epoch [940/1000], Loss: 0.0021, R-squared: 0.9214, MAPE: 24.4738%
# Epoch [950/1000], Loss: 0.0023, R-squared: 0.9141, MAPE: 31.2707%
# Epoch [960/1000], Loss: 0.0022, R-squared: 0.9147, MAPE: 27.9941%
# Epoch [970/1000], Loss: 0.0023, R-squared: 0.9122, MAPE: 26.7446%
# Epoch [980/1000], Loss: 0.0023, R-squared: 0.9112, MAPE: 31.5169%
# Epoch [990/1000], Loss: 0.0022, R-squared: 0.9170, MAPE: 27.7357%
# Epoch [1000/1000], Loss: 0.0023, R-squared: 0.9139, MAPE: 35.6001%
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            896
# ├─LeakyReLU: 1-2                         --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            16,512
# ├─LeakyReLU: 1-5                         --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            129
# =================================================================
# Total params: 17,537
# Trainable params: 17,537
# Non-trainable params: 0
# =================================================================
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
# Sample_2                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
# Sample_2                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_2                       2          0.0         0.108139
# Sample_2                       2          0.2         0.109122
# Sample_2                       2          0.4         0.110435
# Sample_2                       2          0.6         0.112813
# Sample_2                       2          0.8         0.116512
# Sample_2                       2          1.0         0.121249
# Sample_2                       2          1.2         0.126467
# Sample_2                       2          1.4         0.132460
# Sample_2                       2          1.6         0.138644
# Sample_2                       2          1.8         0.146650
# Sample_2                       2          2.0         0.155637
# Sample_2                       2          2.2         0.166771
# Sample_2                       2          2.4         0.178831
# Sample_2                       2          2.6         0.192291
# Sample_2                       2          2.8         0.201551
# Sample_2                       2          3.0         0.207697
# Sample_2                       2          3.2         0.213002
# Sample_2                       2          3.4         0.215464
# Sample_2                       2          3.6         0.216701
# Sample_2                       2          3.8         0.217577
# Sample_2                       2          4.0         0.218010
# Sample_2                       2          4.2         0.214706
# Sample_2                       2          4.4         0.200778
# Sample_2                       2          4.6         0.184393
# Sample_2                       2          4.8         0.168049
# Sample_2                       2          5.0         0.153595
# Sample_2                       2          5.2         0.143603
# Sample_2                       2          5.4         0.134034
# Sample_2                       2          5.6         0.126358
# Sample_2                       2          5.8         0.122172
# Sample_2                       2          6.0         0.118752
# Sample_2                       2          6.2         0.115307
# Sample_2                       2          6.4         0.112294
# Sample_2                       2          6.6         0.110279
# Sample_2                       2          6.8         0.108451
# Sample_2                       2          7.0         0.106606
# Sample_2                       2          7.2         0.104753
# Sample_2                       2          7.4         0.102874
# Sample_2                       2          7.6         0.101037
# Sample_2                       2          7.8         0.099484
# Sample_2                       2          8.0         0.097996
# Sample_2                       2          8.2         0.096596
# Sample_2                       2          8.4         0.095203
# Sample_2                       2          8.6         0.093837
# Sample_2                       2          8.8         0.092403
# Sample_2                       2          9.0         0.090270
# Sample_2                       2          9.2         0.088044
# Sample_2                       2          9.4         0.085869
# Sample_2                       2          9.6         0.083693
# Sample_2                       2          9.8         0.081405
# Sample_2                       2         10.0         0.079028

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
def moving_average(data, window_size):
    ma = np.zeros(len(data))
    for i in range(window_size, len(data) + 1):
        ma[i - 1] = np.mean(data[i - window_size:i])
    return ma

# Set the window size for the moving average
window_size = 4

# Calculate the moving average of the predictions

smooth_smp_FFN = smp2_pred_FFN.copy()
smooth_smp_FFN['Set_voltage_kde'] = moving_average(smp2_pred_FFN['Set_voltage_kde'], window_size)

# Now you can use the smoothed predictions for visualization or further analysis
#display(smooth_smp_FFN)

# %%
ax = plt.gca()
smp2_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp2_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp2_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#FFD700', ax=ax,label="FFN")
smp2.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
plt.legend(prop={'size': 16})
plt.savefig('Figures/Leave_One_Out_Sample_1.jpg',dpi=300)
plt.show()
