# %%
import pandas as pd
import numpy as np
import nbimporter
from MLModels import mlModels
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
#display(setVoltageDf)

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp5 = setVoltageDf.loc['Sample_5']
smp5_X = smp5.drop('Set_voltage_kde',axis=1)
smp5_y = smp5['Set_voltage_kde']
display(smp5_X)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# ...                           ...                  ...
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
# Sample_5                    140.0                  4.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_5                         0                          1
# Sample_5                         0                          1
# Sample_5                         0                          1
# ...

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_5')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_5'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
reg_Models = mlModels()
reg_Models.runModels(X,y,grid_search=False)
# Out:
# Random Forest Regression Mean squared error: 0.00000
# Coefficient of determination: 0.99998
#
#
# Adaboost Regression Mean squared error: 0.00425
# Coefficient of determination: 0.66762

# %%
smp5_pred_ada = smp5_X.copy()
smp5_pred_ada['Set_voltage_kde'] = reg_Models.newSample(smp5_X,'ada')
#smp5_pred_ada
# Out:
# Ada Boost:  [0.08882419 0.08882419 0.08882419 ... 0.07755869 0.07755869 0.07755869]

# %%
smp5_pred_rfr = smp5_X.copy()
smp5_pred_rfr['Set_voltage_kde'] = reg_Models.newSample(smp5_X,'rfr')
#smp5_pred_rfr
# Out:
# Random Forest:  [0.1144093  0.11508375 0.11658068 ... 0.00802916 0.00822182 0.00836817]

# %%
# Load the dataframes

setVoltageDf =  pd.read_csv('process_data/setValues_KDE.csv')

setVoltageDf.set_index('Sample', inplace=True)
setVoltageDf = setVoltageDf.drop(index='Sample_5')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_5'
if s_idx in idx:
    raise ValueError('Sample in Training set')
display(setVoltageDf)

X_train = setVoltageDf.drop('Set_voltage_kde',axis=1)
y_train = setVoltageDf['Set_voltage_kde']

# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1500         
}

model = NeuralNet(X_scaled,y_train,parameters).to(device)
model.train_model()
scaled_smp5_X = standard_scaler.transform(smp5_X)
smp5_pred_FFN = model.testSample(scaled_smp5_X,smp5_X)
display(smp5_pred_FFN)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
def moving_average(data, window_size):
    ma = np.zeros(len(data))
    for i in range(window_size, len(data) + 1):
        ma[i - 1] = np.mean(data[i - window_size:i])
    return ma

# Set the window size for the moving average
window_size = 4

# Calculate the moving average of the predictions

smooth_smp_FFN = smp5_pred_FFN.copy()
smooth_smp_FFN['Set_voltage_kde'] = moving_average(smp5_pred_FFN['Set_voltage_kde'], window_size)

# Now you can use the smoothed predictions for visualization or further analysis
#display(smooth_smp_FFN)

# %%
ax = plt.gca()
smp5_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost", linestyle=':')
smp5_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="Random Forest", linestyle='-.')
smp5_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="FFN", linestyle='--')
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
#smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample E')
plt.tight_layout()
plt.savefig('Figures/Leave_One_Out_Sample_5.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp5_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/ADA_Sample_5.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp5_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/RFR_Sample_5.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp5_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
smp5.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
plt.legend(prop={'size': 16})
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample E')
plt.tight_layout()
plt.savefig('Figures/FFN_Sample_5.jpg',dpi=300)
plt.show()

# %%
from frechetdist import frdist
s_rfr = np.array(smp5_pred_rfr['Set_voltage_kde'].values).reshape(-1,1)
s_ada = np.array(smp5_pred_ada['Set_voltage_kde'].values).reshape(-1,1)
s_true = np.array(smp5['Set_voltage_kde'].values).reshape(-1,1)
s_FFN = np.array(smp5_pred_FFN['Set_voltage_kde'].values).reshape(-1,1)

print("Frechet distance Ada:",frdist(s_ada,s_true))
print("Frechet distance RFR:",frdist(s_rfr,s_true))
print("Frechet distance FFN:",frdist(s_FFN,s_true))
# Out:
# Frechet distance Ada: 0.0724221530649319
# Frechet distance RFR: 0.058528882757929196
# Frechet distance FFN: 0.01934665527029371

# %%
from scipy.stats import wasserstein_distance
s_true = np.array(smp5['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_FFN = np.array(smp5_pred_FFN['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_ada = np.array(smp5_pred_ada['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_rfr = np.array(smp5_pred_rfr['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()

# Calculate Wasserstein distance
print("Wasserstein distance Ada:", wasserstein_distance(s_ada, s_true))
print("Wasserstein distance rfr:", wasserstein_distance(s_rfr, s_true))
print("Wasserstein distance FFN:", wasserstein_distance(s_FFN, s_true))
# Out:
# Wasserstein distance Ada: 0.030894918531114597
# Wasserstein distance rfr: 0.017774318051695697
# Wasserstein distance FFN: 0.013592019221449614
