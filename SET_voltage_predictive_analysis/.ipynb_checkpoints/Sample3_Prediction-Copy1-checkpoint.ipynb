# %%
import pandas as pd
import numpy as np
import nbimporter
from MLModels import mlModels
from FeedForwardNetwork import NeuralNet, save_summary_as_image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# Device configuration: check if there is a configured GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the dataframes
setVoltageDf = pd.read_csv('process_data/setValues_KDE.csv')
setVoltageDf.set_index('Sample', inplace=True)
#display(setVoltageDf)

# %% [markdown]
# # Isolate the Fabrication Sample

# %%
smp3 = setVoltageDf.loc['Sample_3']
smp3_X = smp3.drop('Set_voltage_kde',axis=1)
smp3_y = smp3['Set_voltage_kde']
display(smp3_X)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# ...                           ...                  ...
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# ...                            ...                        ...
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
#
#           Top electrode material  SET Voltage
# Sample
# Sample_3                       2         0.00
# Sample_3                       2         0.01
# Sample_3                       2         0.02
# Sample_3                       2         0.03
# Sample_3                       2         0.04
# ...                          ...          ...
# Sample_3                       2         9.96
# Sample_3                       2         9.97
# Sample_3                       2         9.98
# Sample_3                       2         9.99
# Sample_3                       2        10.00
#
# [1001 rows x 6 columns]

# %%
setVoltageDf = setVoltageDf.drop(index='Sample_3')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_3'
if s_idx in idx:
    raise ValueError('Sample in Training set')

# %%
X = setVoltageDf.drop('Set_voltage_kde',axis=1)
y = setVoltageDf['Set_voltage_kde']

# %%
setVoltageDf.index.unique()
# Out:
# Index(['Sample_1', 'Sample_2', 'Sample_4', 'Sample_5', 'Sample_6', 'Sample_7',
#        'Sample_8'],
#       dtype='object', name='Sample')

# %%
reg_Models = mlModels()
reg_Models.runModels(X,y,grid_search=False)
# Out:
# Random Forest Regression Mean squared error: 0.00000
# Coefficient of determination: 0.99993
#
#
# Adaboost Regression Mean squared error: 0.00520
# Coefficient of determination: 0.63470

# %%
smp3_pred_ada = smp3_X.copy()
smp3_pred_ada['Set_voltage_kde'] = reg_Models.newSample(smp3_X,'ada')
#smp3_pred_ada
# Out:
# Ada Boost:  [0.07508552 0.07508552 0.07508552 ... 0.07517408 0.07517408 0.07517408]

# %%
smp3_pred_rfr = smp3_X.copy()
smp3_pred_rfr['Set_voltage_kde'] = reg_Models.newSample(smp3_X,'rfr')
#smp3_pred_rfr
# Out:
# Random Forest:  [0.0165561  0.01677057 0.0172651  ... 0.00798091 0.00824612 0.00839464]

# %%
# Load the dataframes

setVoltageDf =  pd.read_csv('process_data/setValues_KDE.csv')

setVoltageDf.set_index('Sample', inplace=True)
setVoltageDf = setVoltageDf.drop(index='Sample_3')
idx = setVoltageDf.index.unique()
s_idx = 'Sample_3'
if s_idx in idx:
    raise ValueError('Sample in Training set')
display(setVoltageDf)

X_train = setVoltageDf.drop('Set_voltage_kde',axis=1)
y_train = setVoltageDf['Set_voltage_kde']

# Standard Scaling (Z-score normalization)
standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X_train)


parameters = {
    "input_size":6, 
    "hidden_size":128, 
    "output_size":1,
    "batch_size": 100,   
    "learning_rate": 0.001,
    "num_epochs": 1500         
}

model = NeuralNet(X_scaled,y_train,parameters).to(device)
model.train_model()
scaled_smp3_X = standard_scaler.transform(smp3_X)
smp3_pred_FFN = model.testSample(scaled_smp3_X,smp3_X)
display(smp3_pred_FFN)
# Out:
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# Sample_1                    140.0                  2.0
# ...                           ...                  ...
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
# Sample_8                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# Sample_1                         0                          0
# ...                            ...                        ...
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
# Sample_8                         1                          1
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_1                       2         0.00     5.502315e-02
# Sample_1                       2         0.01     5.566740e-02
# Sample_1                       2         0.02     5.631634e-02
# Sample_1                       2         0.03     5.696996e-02
# Sample_1                       2         0.04     5.762824e-02
# ...                          ...          ...              ...
# Sample_8                       2         9.96     8.278972e-21
# Sample_8                       2         9.97     6.375870e-21
# Sample_8                       2         9.98     4.906279e-21
# Sample_8                       2         9.99     3.772374e-21
# Sample_8                       2        10.00     2.898191e-21
#
# [7007 rows x 7 columns]
# Epoch [100/1500], Loss: 0.0028, R-squared: 0.7944, MAPE: 1680891357.5638%, RMSE: 0.0530, Explained Variance Score: 0.7945
# Epoch [200/1500], Loss: 0.0013, R-squared: 0.9063, MAPE: 1594440256.7515%, RMSE: 0.0358, Explained Variance Score: 0.9063
# Epoch [300/1500], Loss: 0.0008, R-squared: 0.9400, MAPE: 1299120922.1773%, RMSE: 0.0286, Explained Variance Score: 0.9400
# Epoch [400/1500], Loss: 0.0006, R-squared: 0.9536, MAPE: 1135403576.1083%, RMSE: 0.0252, Explained Variance Score: 0.9536
# Epoch [500/1500], Loss: 0.0005, R-squared: 0.9598, MAPE: 1072147035.0210%, RMSE: 0.0234, Explained Variance Score: 0.9601
# Epoch [600/1500], Loss: 0.0005, R-squared: 0.9636, MAPE: 997319583.6396%, RMSE: 0.0223, Explained Variance Score: 0.9636
# Epoch [700/1500], Loss: 0.0005, R-squared: 0.9653, MAPE: 1032459862.8661%, RMSE: 0.0218, Explained Variance Score: 0.9653
# Epoch [800/1500], Loss: 0.0004, R-squared: 0.9677, MAPE: 947701375.2685%, RMSE: 0.0210, Explained Variance Score: 0.9677
# Epoch [900/1500], Loss: 0.0004, R-squared: 0.9699, MAPE: 1016974544.8692%, RMSE: 0.0203, Explained Variance Score: 0.9699
# Epoch [1000/1500], Loss: 0.0004, R-squared: 0.9714, MAPE: 912176200.1031%, RMSE: 0.0198, Explained Variance Score: 0.9715
# Epoch [1100/1500], Loss: 0.0004, R-squared: 0.9714, MAPE: 949352910.4103%, RMSE: 0.0198, Explained Variance Score: 0.9714
# Epoch [1200/1500], Loss: 0.0004, R-squared: 0.9732, MAPE: 978707596.8211%, RMSE: 0.0191, Explained Variance Score: 0.9732
# Epoch [1300/1500], Loss: 0.0004, R-squared: 0.9734, MAPE: 940672378.9137%, RMSE: 0.0191, Explained Variance Score: 0.9735
# Epoch [1400/1500], Loss: 0.0004, R-squared: 0.9737, MAPE: 949352611.9499%, RMSE: 0.0190, Explained Variance Score: 0.9737
# Epoch [1500/1500], Loss: 0.0003, R-squared: 0.9757, MAPE: 997719588.2216%, RMSE: 0.0182, Explained Variance Score: 0.9758
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            896
# ├─LeakyReLU: 1-2                         --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            16,512
# ├─LeakyReLU: 1-5                         --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            16,512
# ├─LeakyReLU: 1-8                         --
# ├─Dropout: 1-9                           --
# ├─Linear: 1-10                           129
# =================================================================
# Total params: 34,049
# Trainable params: 34,049
# Non-trainable params: 0
# =================================================================
#           Baking temperature (°C)  Baking time (hours)  \
# Sample
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# ...                           ...                  ...
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
# Sample_3                     90.0                  8.0
#
#           Resistive switching film  Bottom electrode material  \
# Sample
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# ...                            ...                        ...
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
# Sample_3                         0                          0
#
#           Top electrode material  SET Voltage  Set_voltage_kde
# Sample
# Sample_3                       2         0.00         0.008387
# Sample_3                       2         0.01         0.008729
# Sample_3                       2         0.02         0.009076
# Sample_3                       2         0.03         0.009447
# Sample_3                       2         0.04         0.009817
# ...                          ...          ...              ...
# Sample_3                       2         9.96         0.010329
# Sample_3                       2         9.97         0.010284
# Sample_3                       2         9.98         0.010239
# Sample_3                       2         9.99         0.010195
# Sample_3                       2        10.00         0.010150
#
# [1001 rows x 7 columns]

# %%
save_summary_as_image(model, 'Figures/model_summary2.png', file_format='png')

# %%
def moving_average(data, window_size):
    ma = np.zeros(len(data))
    for i in range(window_size, len(data) + 1):
        ma[i - 1] = np.mean(data[i - window_size:i])
    return ma

# Set the window size for the moving average
window_size = 4

# Calculate the moving average of the predictions

smooth_smp_FFN = smp3_pred_FFN.copy()
smooth_smp_FFN['Set_voltage_kde'] = moving_average(smp3_pred_FFN['Set_voltage_kde'], window_size)

# Now you can use the smoothed predictions for visualization or further analysis
#display(smooth_smp_FFN)

# %%
ax = plt.gca()
smp3_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost", linestyle=':')
smp3_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="Random Forest", linestyle='-.')
smp3_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="FFN", linestyle='--')
smp3.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
#smooth_smp_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample C')
plt.tight_layout()
plt.savefig('Figures/Leave_One_Out_Sample_3.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp3_pred_ada.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#4CAF50', ax=ax,label="Adaboost")
smp3.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/ADA_Sample_3.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp3_pred_rfr.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#C20078', ax=ax,label="Random Forest")
smp3.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
#plt.legend(prop={'size': 16})
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('Figures/RFR_Sample_3.jpg',dpi=300)
plt.show()

# %%
ax = plt.gca()
smp3_pred_FFN.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='Orange', ax=ax,label="FFN")
smp3.plot(kind='line',x='SET Voltage',y='Set_voltage_kde', color='#069AF3', ax=ax,label="True")
plt.rcParams["figure.figsize"] = (10,6.5)
plt.rcParams.update({'font.size': 14})
plt.ylabel("Density")
plt.legend(prop={'size': 16})
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Sample C')
plt.tight_layout()
plt.savefig('Figures/FFN_Sample_3.jpg',dpi=300)
plt.show()

# %%
from frechetdist import frdist
s_rfr = np.array(smp3_pred_rfr['Set_voltage_kde'].values).reshape(-1,1)
s_ada = np.array(smp3_pred_ada['Set_voltage_kde'].values).reshape(-1,1)
s_true = np.array(smp3['Set_voltage_kde'].values).reshape(-1,1)
s_FFN = np.array(smp3_pred_FFN['Set_voltage_kde'].values).reshape(-1,1)

print("Frechet distance Ada:",frdist(s_ada,s_true))
print("Frechet distance RFR:",frdist(s_rfr,s_true))
print("Frechet distance FFN:",frdist(s_FFN,s_true))
# Out:
# Frechet distance Ada: 0.30484517854796245
# Frechet distance RFR: 0.040779316753629724
# Frechet distance FFN: 0.012742394346883356

# %%
from scipy.stats import wasserstein_distance
s_true = np.array(smp3['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_FFN = np.array(smp3_pred_FFN['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_ada = np.array(smp3_pred_ada['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()
s_rfr = np.array(smp3_pred_rfr['Set_voltage_kde'].values).reshape(-1,1).ravel().tolist()

# Calculate Wasserstein distance
print("Wasserstein distance Ada:", wasserstein_distance(s_ada, s_true))
print("Wasserstein distance rfr:", wasserstein_distance(s_rfr, s_true))
print("Wasserstein distance FFN:", wasserstein_distance(s_FFN, s_true))
# Out:
# Wasserstein distance Ada: 0.04957819883256572
# Wasserstein distance rfr: 0.024168309317157702
# Wasserstein distance FFN: 0.025612758184538918
